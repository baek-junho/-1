# %% [markdown]
# # 지도시각화하기

# %%
# 지도시각화를 위해 folium 라이브러리를 사용하겠습니다. 
import folium

# %%
# 설치하기: folium  라이브러리가 설치되어 있지 않다면, 아래 라인의 코드에서 # 기호를 없애 주석 해제하고 실행하시면 됩니다. 
# ! pip install folium
# Out:
# Requirement already satisfied: folium in c:\programdata\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: jinja2>=2.9 in c:\programdata\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in c:\programdata\anaconda3\lib\site-packages (from folium) (1.16.5)
# Requirement already satisfied: branca>=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.14.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus= False)
plt.style.use('ggplot')
pd.options.display.max_columns  = 100

# %% [markdown]
# ## 지도 시각화
# - 지도생성하기
#     - `m` = folium.Map(location = [위도, 경도],  zoom_start = 확대정도)
#
# - 정보 추가하기
#     - 마커 추가하기
#         - folium.Marker([위도, 경도]).add_to(`m`)
#     - 원 추가하기
#         -     folium.CircleMarker([위도, 경도],radius= 원크기).add_to(`m`)
#     - 추가옵션:
#         - tooltip="마우스 올리면 보여질 정보"
#         - popup="클릭하면 보여질 정보"
#     - 기타) ClickForMarker('체크').add_to(`m`)  지도에서 클릭할 경우 마커 추가하기

# %%
# 지도 생성하기
# 먼저, 지도를 펼쳐야 합니다.  지도에서 어느 부분을 살펴볼 것인지, 지도 중심의 좌표를 위도, 경도를 이용해 지정해야 합니다. 
# 서울역을 기준으로 살펴보겠습니다. 
# zoom_start 옵션을 통해, 처음에 얼마나 확대해서 볼 것인지를 지정할 수 있습니다. 
# 지도가 생성된 뒤에 위치 이동이나 확대/축소를 조정할 수도 있습니다. 
m = folium.Map(location=[37.5536067,126.9674308],   # 기준좌표: 서울역)
               zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Marker( [위도, 경도]).add_to(지도이름) 명령을 통해 지도상에 마커를 추가할 수 있으며
# tooltip, popup 옵션을 통해 설명을 추가할 수 있습니다. 

# 마커 추가하기
folium.Marker([37.5536067,126.9674308],    # 서울역위치
              tooltip="서울역(마우스올리면보여짐)",
              popup="서울역(클릭하면 보여짐)",
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# CircleMarker( [ 위도, 경도]).add_to(지도이름) 명령을 통해, 동그라미를 지도에 표시할 수 있습니다. 
# 이때 radius 옵션을 통해 동그라미의 크기를 지정할 수 있습니다. 

# 써클마커 추가하기
folium.CircleMarker([37.5536067,126.9674308],
                    radius=20,
                    tooltip = '마우스올릴경우'
               ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 미니맵을 추가할 경우 MiniMap

# %%
# folium에는 다양한 효과를 줄 수 있는 plugins 이 존재 하는데, MiniMap 도 그 중 하나 입니다. 
# 미니맵을 지도 우측 하단에 추가하여, 현재 어느 위치를 살펴보고 있는지 점검할 수도 있습니다. 

from folium.plugins import MiniMap

# 지도 생성하기
m = folium.Map(location=[37.5536067,126.9674308],   # 기준좌표: 서울역
               zoom_start=12)

# 미니맵 추가하기
minimap = MiniMap() 
minimap.add_to(m)


# 마커 추가하기
folium.Marker([37.5536067,126.9674308],    # 서울역위치
              tooltip="서울역(마우스올리면보여짐)",
              popup="서울역(클릭하면 보여짐)",
              ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 지도에서 표시를 추가하고 싶을때: ClickForMarker

# %%
# 모든 정보를 처음부터 지도에 추가하지 않고, 이후에 마우스를 이용해 추가할 수 있도록 만들 수도 있습니다. 

# 지도 생성하기
m = folium.Map(location=[37.5536067,126.9674308],   # 기준좌표: 서울역
               zoom_start=12)

# 써클마커 추가하기
folium.CircleMarker([37.5536067,126.9674308],
                    radius=20,
                    tooltip = '마우스올릴경우'
               ).add_to(m)
folium.ClickForMarker('체크추가').add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 서울 대피소 현황 지도 만들기

# %% [markdown]
# 서울 대피소 현황 자료를 다운받아 이를 지도에 시각화 해보겠습니다.

# %%
# csv파일의 표 형태 데이터를 읽어오기 위해 판다스를 불러옵니다. 
import pandas as pd

# %%
# 서울열린데이터광장에 있는 서울시 대피소 현황 자료를 다운 받고, 판다스로 조회하겠습니다. 
# 서울 대피소 현황 자료 다운받기
# http://data.seoul.go.kr/dataList/OA-2189/S/1/datasetView.do
file = './data/서울시 대피소 방재시설 현황 (좌표계_ WGS1984).csv'
raw = pd.read_csv(file, encoding = 'cp949')   # encoding = 'cp949' : MS 프로그램 사용시,   그외의 경우 encoding = 'utf-8'  (기본값)

# %%
# 파일에서 읽어온 데이터를 살펴보겠습니다. 
raw.head()
# Out:
#    고유번호     대피소명칭                소재지  최대수용인원  현재수용인원 현재운영여부           전화번호  \
# 0     2    혜화초등학교  혜화동 13-1 (혜화로 32)     450       0      N       763-0606
# 1     3      새샘교회           홍제동 20-4     100       0      N       720-7040
# 2     4    한강중앙교회     포은로2가길 66(합정동)     130       0      N       337-6629
# 3     5  서울성산초등학교      양화로3길 94(합정동)     200       0      N       324-1407
# 4     6   상도1동경로당        상도동 159-282      20       0      N  010-8011-7330
#
#       행정동코드 행정동명칭 대피단계 비고          경도         위도
# 0  11110650   혜화동          126.999891  37.589128
# 1  11410655  홍제2동          126.950484  37.583660
# 2  11440680   합정동          126.910028  37.549343
# 3  11440680   합정동          126.910666  37.553495
# 4  11590530  상도1동          126.948269  37.500395

# %%
# 인덱스번호가 0인 경우, 위도와 경도 데이터를 출력해보겠습니다. 

i = 0

lat = raw.loc[i, '위도']
long = raw.loc[i, '경도']
name = raw.loc[i,'대피소명칭']

print(lat, long, name)
# Out:
# 37.5891283 126.9998906 혜화초등학교

# %%
# 모든 인덱스 번호에 대해서 위도,경도, 명칭을 출력해보겠습니다. 
for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i,'대피소명칭']

    print(name, lat, long)
# Out:
# 혜화초등학교 37.5891283 126.9998906
# 새샘교회 37.58366029999999 126.95048440000001
# 한강중앙교회 37.5493434 126.91002809999999
# 서울성산초등학교 37.553495299999994 126.9106658
# 상도1동경로당 37.500395399999995 126.9482686
# 상도초등학교 37.4997347 126.93743229999998
# 본동초교 37.5100544 126.9536402
# 남정초등학교 37.5365343 126.9650202
# 응암초등학교 37.5884354 126.92177849999999
# 제일감리교회 37.5030252 126.9625144
# 봉천종합사회복지관 37.4866976 126.9576162
# 여의도초등학교 37.52320770000001 126.93680970000001
# 사당1동주민센터 37.4830902 126.9787764
# 서부성결교회 37.5283727 126.95371019999999
# 서울 이수 중학교 37.4811316 126.9901108
# 서울공덕초등학교 37.5459029 126.9535807
# 국사봉중학교 37.4937422 126.9440685
# 봉현초등학교 37.4910611 126.9553258
# 천주교 외방선교회 37.5911343 127.0021399
# 성동세무서 37.5484412 127.0628283
# 방이중학교 37.5147612 127.1130378
# 가락초등학교 37.49982979999999 127.1079155
# 성수초교 37.5444065 127.0629919
# 잠신초등학교 37.515907299999995 127.08781440000001
# 태화기독교종합 사회복지관 37.484888 127.0934544
# 잠실중학교 37.51723320000001 127.09934399999999
# 정릉초등학교 37.619831700000006 127.0055226
# 광양중학교 37.530351200000005 127.08535230000001
# 대광고등학교 37.577849799999996 127.02442759999998
# 성실교회교육관 37.6403265 127.0229092
# 가원초등학교 37.489181200000004 127.1112013
# 도봉중학교 37.670891600000004 127.0457558
# 쌍문4동주민센터 37.6564809 127.02840139999999
# 방배2동 주민센터 37.4797843 126.98561229999999
# 보인고등학교 37.497946999999996 127.13944779999999
# 개포초등학교 37.4868368 127.0704134
# 마천초등학교 37.4955053 127.1526489
# 학마을다사랑센터 37.6621603 127.0278544
# 보성중고등학교 37.5197002 127.13485700000001
# 길동초등학교 37.538511 127.14487220000001
# 안암초등학교 37.587503000000005 127.02247209999999
# 장위1동 주민센터 37.6140774 127.04367509999999
# 창일중학교 37.6488034 127.04675800000001
# 남현교회 37.499126700000005 127.1001476
# 잠실여자고등학교 37.5023094 127.11307190000001
# 명일초등학교 37.5544231 127.14202790000002
# 개웅초등학교 37.4885099 126.85008459999999
# 성결교회 37.515637 126.88948719999999
# 한천초등학교 37.6205029 127.06885919999999
# 영일초등학교 37.4853903 126.8838479
# 화곡 경로당 37.5321157 126.84779540000001
# 대길초등학교 37.498326500000005 126.9134649
# 중현초등학교 37.6323901 127.06607939999999
# 신남초등학교 37.5162167 126.8440456
# 고덕2동 주민센터 37.560523100000005 127.16437579999999
# 영원중학교 37.5154717 126.9140858
# 우정 경로당 37.574565899999996 126.8185847
# 수궁동 주민센터 37.493891 126.8314824
# 연세중앙교회 37.495209 126.8352071
# 천주교살레시오회 37.5015627 126.9090253
# 염경초등학교 37.554995 126.87128999999999
# 강현중학교 37.503100700000005 126.93084479999999
# 중계초등학교 37.6577443 127.07329969999999
# 서울남교회 37.4881908 126.88205420000001
# 중앙고등학교 37.5840138 126.9868971
# 거여초등학교 37.505164 127.14089779999999
# 세곡초등학교 37.5050993 126.8490857
# 치현 경로당 37.5798578 126.81532709999999
# 영서중학교 37.4893503 126.894405
# 동명초교 37.568855299999996 127.035735
# 대림감리교회 37.4940691 126.9098472
# 영신초등학교 37.5100825 126.91797820000001
# 신영초등학교 37.50069620000001 126.89580890000002
# 정목초등학교 37.53733629999999 126.87029299999999
# 성심여고 37.534974 126.95320149999999
# 숭문중고등학교 37.5515947 126.9451277
# 신상도초등학교 37.500352899999996 126.94409909999999
# 도원동교회 37.538875 126.9577723
# 흑석초등학교 37.5084712 126.96562040000002
# 은천동주민센터 37.4853098 126.94245729999999
# 금호초교 37.552715 127.01998490000001
# 용강초등학교 37.548769 126.9436862
# 자교교회 37.5811339 126.9714765
# 종로문화체육센터 37.574225 126.9646777
# 창신초등학교 37.5762443 127.0144101
# 이태원초등학교 37.5362084 126.9881882
# 북가좌초등학교 37.577710100000004 126.90763390000002
# 정릉교회(교육관) 37.6030314 127.01424329999999
# 경복고등학교 37.587081 126.97165459999998
# 서울예술고등학교 37.605569 126.968525
# 서현교회 37.552792700000005 126.9160894
# 영중초등학교 37.5238286 126.9039522
# 선유정보문화도서관 37.5332365 126.8929147
# 종로노인종합복지관 37.576666700000004 127.0060369
# 성일중학교 37.5814717 127.0341328
# 건국대학교부속중학교 37.541191999999995 127.08167759999998
# 전농2동 주민센터 37.5784972 127.0576385
# 청량중학교 37.588003 127.05108510000001
# 단대부고체육관 37.495566600000004 127.0564098
# 송파공업고등학교 37.491659000000006 127.14209
# 천호1동 주민센터 37.5450331 127.1368227
# 신구초등학교 37.5233225 127.02389939999999
# 샛터경로당 37.5671689 126.908768
# 혜원여자고등학교 37.592814000000004 127.09677179999998
# 숭덕초등학교(교사동) 37.6046427 127.01403130000001
# 삼광초등학교 37.547312700000006 126.9768736
# 둔촌2동 주민센터 37.533349900000005 127.14196559999999
# 이문1동 주민센터 37.5978229 127.06551200000001
# 삼성2문화복지회관 37.5112094 127.0459862
# 아주중학교 37.5044359 127.07556240000001
# 중랑청소년수련관 37.5732279 127.08599720000001
# 용곡중학교 37.565837200000004 127.08929440000001
# 면남초등학교 37.5770708 127.08828510000001
# 번동중학교 37.6324049 127.0360585
# 남천초등학교 37.5010971 127.15027930000001
# 답십리1동 주민센터 37.571937 127.05117890000001
# 월곡초등학교 37.610026500000004 127.046097
# 대치1문화센터 37.49325579999999 127.05679950000001
# 수서초등학교 37.4910227 127.1016166
# 염창강변 경로당 37.551522399999996 126.8758771
# 덕의초등학교 37.5063495 126.8568307
# 문창초등학교 37.4892126 126.9141494
# 신월중학교 37.540477100000004 126.8283968
# 우장초등학교 37.5491882 126.84605249999998
# 계남초등학교 37.510133200000006 126.8601557
# 예촌 경로당 37.5304363 126.8421456
# 가산중학교 37.4683134 126.8941597
# 당산천주교회 37.5248657 126.8981321
# 서울공업고등학교 37.501616299999995 126.92227690000001
# 강월초등학교 37.516043700000004 126.8336364
# 신목고등학교 37.5127692 126.8743889
# 신곡 경로당 37.5367069 126.8545682
# 영동초등학교 37.5268479 126.90765990000001
# 양원초등학교 37.5383352 126.8234956
# 화친 경로당 37.531111700000004 126.8594439
# 가곡초등학교 37.555671600000004 126.83594380000001
# 당산2동 주민센터 37.5347151 126.90210230000001
# 석관고등학교 37.6100943 127.066135
# 상계중학교 37.6524153 127.068871
# 영등포고등학교 37.508478600000004 126.9341598
# 천호초등학교 37.5470114 127.1369688
# 영도중학교 37.5359049 126.86600779999999
# 고척초등학교 37.5009264 126.85724760000001
# 양동중학교 37.5481433 126.86870390000001
# 신길3동구립경로동 37.508517299999994 126.9065702
# 한민교회 37.52263610000001 126.84537879999999
# 덕산중학교 37.601977399999996 126.90437879999999
# 가산초등학교 37.4782029 126.8963861
# 신구로초등학교 37.4995867 126.8892791
# 신정사회복지관 37.526453499999995 126.8604868
# 대원고등학교 37.5644753 127.08351979999999
# 서울신방학초등학교 37.6660552 127.02916499999999
# 대치4문화센터 37.499826500000005 127.05780549999999
# 서울광장초등학교 37.5485021 127.1011402
# 면일초등학교 37.5920562 127.09983840000001
# 송파초등학교 37.507363299999994 127.1111866
# 구의중학교 37.542885600000005 127.0792352
# 서울초당초등학교 37.6583129 127.02198359999998
# 방학중학교 37.665665600000004 127.0314118
# 양진중학교 37.5450598 127.09835929999998
# 무학여고 37.5572727 127.0332743
# 선화예술고등학교 37.5508795 127.08798359999999
# 청담고등학교 37.5280392 127.0437328
# 오남중학교 37.4872623 126.8371987
# 노량진초교 37.5112156 126.9409405
# 양평2동 주민센터 37.537743400000004 126.8959355
# 유현초등학교 37.631741999999996 127.0113905
# 삼전초등학교 37.5017232 127.09275339999999
# 효문고등학교 37.65265 127.0183509
# 광양고등학교 37.5293434 127.0850088
# 성내동교회 37.534161 127.1251979
# 용동초등학교 37.6418513 127.0692587
# 고명초등학교 37.5527209 127.14650209999999
# 시흥초등학교 37.4549744 126.9049492
# 양강초등학교 37.5243318 126.84800420000002
# 문래동 성당 37.517302799999996 126.890644
# 도림초등학교 37.5080706 126.90691140000001
# 곰달래 경로당 37.529648 126.84076850000001
# 구로5동 주민센터 37.5001732 126.88928259999999
# 행당초교 37.556548 127.0346801
# 여의도여자고등학교 37.5229564 126.93486940000001
# 일원초등학교 37.4898178 127.076323
# 용산초등학교 37.5356176 126.97257090000001
# 신목초등학교 37.5171806 126.87260459999999
# 목일중학교 37.513513200000006 126.87375300000001
# 개포중학교 37.48058220000001 127.0618915
# 서울여자고등학교 (체 37.5479846 126.9482633
# 휘경중학교 37.5869435 127.06263159999999
# 양화중학교 37.5195144 126.895944
# 잠실초등학교 37.520251200000004 127.1108977
# 일심 경로당2 37.5668755 126.81602659999999
# 매봉초등학교 37.5045585 126.84445259999998
# 양남초등학교 37.5310602 127.0897244
# 중화초등학교 37.60333 127.09428229999999
# 장안1동 주민센터 37.5677935 127.0665531
# 시영경로당 37.5585842 127.1490669
# 구립용왕경로당 37.5462225 126.8797749
# 홍제1동주민센터 37.587699900000004 126.94489509999998
# 암사1동 주민센터 37.5514658 127.13266979999999
# 충신교회 37.5818448 126.91075
# 마리스타교육관 37.544860899999996 126.91390849999999
# 구립창신경로당 37.5099704 126.92068789999999
# 매동초등학교 37.5775087 126.9669392
# 등서초등학교 37.5518833 126.85505819999999
# 안골 경로당 37.536006 126.85078290000001
# 양동초등학교 37.525854700000004 126.8512654
# 명지대방목학술정보관 37.5803467 126.9231625
# 인왕중학교 37.5927763 126.95172209999998
# 내발산초등학교 37.551610600000004 126.83793090000002
# 삼오경로당 37.5821284 126.9218074
# 구립양화경로당 37.5428831 126.8899568
# 교동초등학교 37.5749875 126.9881341
# 역삼1동문화센터 37.495335 127.03325600000001
# 강서초등학교 37.5224143 126.8409982
# 동부 경로당 37.572520399999995 126.81989679999998
# 둔촌초등학교 37.526241 127.1372817
# 대원여자고등학교 37.56281920000001 127.08881170000001
# 불암초등학교 37.651165 127.0805707
# 천호중학교 37.546756099999996 127.1395344
# 성내초등학교 37.53151 127.12267299999999
# 면목초등학교 37.5913201 127.08769960000001
# 청담초등학교 37.5282805 127.04516159999999
# 서울쌍문초등학교 37.648971200000005 127.02440520000002
# 중랑초등학교 37.5895902 127.07556969999999
# 공릉초등학교 37.6193069 127.07425309999999
# 강일동 주민센터 37.564982799999996 127.17403610000001
# 고덕1동 주민센터 37.5590548 127.14891979999999
# 면동초등학교 37.585426899999995 127.0863636
# 면목고등학교 37.584398799999995 127.09724650000001
# 한빛사회복지관 37.5190795 126.8402446
# 상봉중학교 37.601554 127.0901155
# 방산초등학교 37.5095526 127.12109550000001
# 문정중학교 37.48843239999999 127.13025490000001
# 희우경로당 37.5531674 126.90907469999999
# 상일동 주민센터 37.5516092 127.1655314
# 신명초등학교 37.541000700000005 127.1500551
# 영등포동 주민센터 37.5203992 126.9107094
# 우신초등학교 37.50990529999999 126.9118456
# 등촌초등학교 37.5476094 126.8578108
# 용산교회 37.547738 126.9732429
# 북성초등학교 37.55934570000001 126.95178349999999
# 서울제일교회 37.557227399999995 126.96028700000001
# 월곡감리교회 37.602976700000006 127.04039820000001
# 홍제초등학교 37.592688 126.9442854
# 답십리초등학교 37.5688794 127.05547790000001
# 신용산초등학교 37.5202766 126.9764757
# 능안 경로당 37.5466468 126.85992399999999
# 성산성결교회 37.550538 126.90814840000002
# 서울중동초(정보관2층 다목적실) 37.566879 126.911639
# 신사초등학교 37.59283679999999 126.91200549999999
# 길 동 주민센터 37.53923220000001 127.1462094
# 까치산 경로당 37.5367691 126.84139669999999
# 하마터 경로당 37.530117700000005 126.85377109999999
# 무악동주민센터 37.57598370000001 126.958142
# 월드비전교회 37.4895328 126.9242737
# 재동초등학교 37.57989 126.98568700000001
# 북부경로당 37.540477100000004 126.9925577
# 경복초등학교 37.5498184 127.0868094
# 덕성여자대학교 37.651461 127.0166893
# 중화고등학교 37.6045778 127.0836716
# 전농1동 주민센터 37.5779753 127.0477473
# 서울신화초등학교 37.6327676 127.04105849999999
# 면목중학교 37.583068100000006 127.0965898
# 동신초등학교 37.5827189 127.01673729999999
# 양화진경로당 37.5466977 126.91239479999999
# 한남초등학교 37.5393765 127.0048805
# 동신중학교 37.536781 127.13311000000002
# 동대문중학교 37.5745689 127.05151540000001
# 서울조원초등학교 37.4841727 126.9095481
# 인창중학교 37.565365500000006 126.9642416
# 천호2동 주민센터 37.5426007 127.1207594
# 양진초등학교 37.5442532 127.09854229999999
# 성서중학교 37.5628448 126.90911809999999
# 수도여자고등학교 37.4930758 126.9155706
# 인헌초등학교체육관 37.4759283 126.96062909999999
# 양화초등학교 37.54376129999999 126.8753459
# 영등포초등학교 37.5129485 126.89827360000001
# 서울 방배 초등학교 37.4872461 126.9878564
# 연희동자치회관 37.569331899999995 126.93082700000001
# 상암초등학교 (체육관 37.5761802 126.8921946
# 장훈고등학교 37.5130079 126.9150892
# 대림중학교 37.4922269 126.9070193
# 문창중학교 37.4958165 126.9223506
# 건국대학교 사범대학 37.543197 127.077444
# 상록보육원 37.4736571 126.9766545
# 봉제 경로당 37.5457403 126.8516996
# 영은교회 37.5252916 126.8900051
# 도림천주교회 37.5105206 126.9014245
# 구립신길5동제2경로당 37.5017643 126.9054364
# 신길7제1구립노인정 37.506452100000004 126.9213962
# 당산1동 주민센터 37.5250013 126.8973782
# 서원동주민센터 37.4797795 126.9313905
# 서울디자인고교 37.5469717 126.94799499999999
# 주영광교회 37.4928824 127.1230627
# 서일정보산업고 37.579311600000004 127.0130043
# 을지교회 37.565625399999995 126.9950263
# 홍파초등학교 37.5861335 127.03938529999999
# 조원동주민센터 37.481173 126.90939170000001
# 방화6복지관 경로당 37.577914 126.81089399999999
# 양강중학교 37.5247969 126.84942720000001
# 대명초등학교 37.54725620000001 127.15280109999999
# 문래중학교 37.520365000000005 126.88470020000001
# 양평1동 주민센터 37.5250278 126.88874209999999
# 신광명 경로당 37.5469102 126.82294740000002
# 동구로초등학교 37.495257200000005 126.8925095
# 석관초등학교 37.6110156 127.05895859999998
# 골안말 경로당 37.533192799999995 126.85624879999999
# 초록동 경로당 37.541129600000005 126.8485221
# 구립당산2동경로당 37.5349407 126.903985
# 돈암초등학교 37.593722799999995 127.0127754
# 양재1동 주민센터 37.471660799999995 127.0266742
# 청담2문화복지회관 37.5191032 127.04646509999998
# 홍연초등학교 37.5820771 126.930903
# 독립문초등학교 37.57431629999999 126.9599977
# 수유2동주민센터 37.644644799999995 127.0199054
# 강동초등학교 37.5462875 127.1300447
# 신흥교회 37.5501539 127.13055870000001
# 강일중학교 37.555367600000004 127.13837350000001
# 신도림동 주민센터 37.5077695 126.8805967
# 구로4동 주민센터 37.4916016 126.88916640000001
# 서광경로당 37.4760768 126.94205179999999
# 창동고등학교 37.6510435 127.03858770000001
# 백운중학교 37.6564921 127.0358902
# 응암감리교회 37.589876200000006 126.91846329999998
# 남성중학교 37.4789456 126.97244340000002
# 오산고교 37.5235333 126.99959309999998
# 보성여고 37.5430897 126.9842846
# 서교감리교회 37.55457 126.9150014
# 송천초등학교 37.615709 127.0233496
# 남일교회 37.488065500000005 126.979165
# 풍문여자고등학교 37.5766446 126.98349420000001
# 효제초등학교 37.5730679 127.0030669
# 한서초등학교 (강당) 37.5536804 126.9493416
# 천호동중앙교회 37.5439769 127.12255630000001
# 서초구청 37.4836201 127.0327209
# 영암교회(교회당) 37.6036604 127.0272595
# 창문여자고등학교 37.613477100000004 127.03644979999999
# 오류2동 주민센터 37.48880870000001 126.8395008
# 구로여자정보산업고등학교 37.5002418 126.8281915
# 대원외국어고등학교 37.5636685 127.0891173
# 선린초등학교 37.529664000000004 127.14553390000002
# 증산중학교 37.5836674 126.9041368
# 서정초등학교 37.524253 126.86710990000002
# 경기상업고등학교 37.588561 126.9699284
# 길음 종합사회복지관 37.6088175 127.02477340000002
# 미양중학교 37.6235791 127.01216869999999
# 청파초등학교 37.5479867 126.9643143
# 무학초교 37.563263799999994 127.02956280000001
# 성원중학교 37.5392935 127.05253950000001
# 서울양재초등학교 37.4741646 127.0319136
# 한남교회 37.5319441 127.00638880000001
# 중대초등학교 37.499813200000006 127.1135969
# 명신초등학교 37.5813782 127.0140632
# 은가경로당 37.5812088 126.9179274
# 종합행정타운 37.5324773 126.9904794
# 마포삼성@경로당 37.5398266 126.95029840000002
# 금화초등학교 37.5680782 126.9630729
# 경문고등학교 37.49235170000001 126.981568
# 대신고등학교 37.57354 126.96184440000002
# 서울사대부속여중 37.5779418 127.0039175
# 오류여자중학교 37.4981483 126.85475290000001
# 암사2동 주민센터 37.5517511 127.1272382
# 중목초등학교 37.590258899999995 127.0793691
# 상현중학교 37.494293 126.9613115
# 미성동주민센터 37.47618189999999 126.915573
# 치현초등학교 37.5759123 126.81462509999999
# 화원중학교 37.5367143 126.84265239999999
# 서울신봉초등학교 37.4856133 126.9491483
# 난우중학교 37.466807200000005 126.9230311
# 광희중학교 37.5510344 127.0342166
# 삼일교회 37.541807299999995 126.96775690000001
# 영광교회 37.5446028 126.932724
# 도림교회 37.5101591 126.8971795
# 구립문래제1경로당 37.5184177 126.8939429
# 상도3동주민센터 37.4991358 126.93141580000001
# 성산중학교 37.5476373 126.9159645
# 당산초등학교 37.539614 126.8963895
# 대영초등학교 37.502675 126.9065507
# 고척1동 주민센터 37.50041220000001 126.86281409999998
# 구립율산경로당 37.5157342 126.9226591
# 구립양평1동경로당 37.5232656 126.88819099999999
# 상수청소년독서실 37.5450991 126.9270335
# 약수 경로당 37.5380081 126.84754620000001
# 영등포동 주민자치회관 37.52548 126.9034287
# 문정초등학교 37.4890451 127.1292892
# 예능교회 37.6071825 126.9695997
# 이문동교회 37.6009825 127.06069840000002
# 미양고등학교 37.623810399999996 127.0123045
# 구립대림2동제2경로당 37.492828100000004 126.8993033
# 세종대학교 군자관 37.549533600000004 127.0739425
# 국일교회 37.5947552 127.0914775
# 갈산초등학교 37.512004 126.86983090000001
# 강동어린이회관 37.5291893 127.12241110000001
# 영도교회 37.5100593 126.9054805
# 용곡초등학교 37.567130799999994 127.08849690000001
# 면중초등학교 37.5823401 127.0965892
# 영서초등학교 37.488599900000004 126.8950267
# 대방중학교 37.495386100000005 126.91363340000001
# 노원초등학교 37.6732718 127.05839840000002
# 이문초등학교 37.6020634 127.06435090000001
# 상일초등학교 37.547300299999996 127.1727125
# 대세빌딩 37.5377898 127.1353379
# 한양감리교회 37.5327075 127.1304647
# 원당 경로당 37.557419 126.84215859999999
# 신길4동 주민센터 37.5083753 126.91124270000002
# 대림초등학교 37.500665500000004 126.9257597
# 신월초등학교 37.5401407 126.83947509999999
# 도봉 문화고등학교 37.6639745 127.04757279999998
# 화곡초등학교 37.542992600000005 126.84590159999998
# 청운초등학교 37.5858134 126.96923740000001
# 창신제일교회 37.575695399999994 127.0100232
# 창덕초등학교 37.6119005 127.0003236
# 거원초등학교 37.4876439 127.14475800000001
# 남명초등학교 37.5154848 126.8539328
# 서울마포초등학교 37.5386231 126.9499885
# 성내도서관 37.5328602 127.1333594
# 숭인제1동주민센터 37.5778373 127.0156471
# 광성중고등학교 37.5487396 126.93636459999999
# 여의도순복음교회 37.5305307 126.92417150000001
# 개봉2동 주민센터 37.4908348 126.85656000000002
# 고척2동 주민센터 37.5065938 126.8584369
# 창천초등학교 37.5547801 126.93943370000001
# 당서초등학교 37.5319345 126.89944240000001
# 숭례초등학교 37.5952013 127.03489309999999
# 배문중고교 37.5498945 126.96391509999998
# 서울소의초등학교 37.55240379999999 126.9606038
# 서강초등학교 37.5484025 126.92707079999998
# 신남성초등학교 37.488975399999994 126.9651091
# 원당초등학교 37.4812536 126.9557108
# 대신초등학교 37.558014899999996 126.9480389
# 사당청소년문화의집 37.4854435 126.9757561
# 남가좌1동 분회경로당 37.569539500000005 126.9167345
# 성북초등학교 37.5938878 126.99812050000001
# 천호초등학교 체육관 37.547516200000004 127.1362174
# 구의초등학교 37.5429207 127.0802659
# 배봉초등학교 37.5802312 127.0660865
# 명일2동 주민센터 37.546363799999995 127.1513797
# 천호2동 주민센터 37.546232700000004 127.13174309999998
# 장평초등학교 37.5738977 127.07291409999998
# 휘경1동 주민센터 37.592920899999996 127.06574769999999
# 원광장애인복지관 37.60402979999999 127.09599920000001
# 묵현초등학교 37.6090393 127.0736452
# 군자초등학교 37.5644518 127.0616104
# 대원중학교 37.563724900000004 127.08948570000001
# 일심 경로당 37.530217799999996 126.85145209999999
# 목동중학교 37.5209583 126.8714642
# 서울삼성초등학교 37.4677782 126.94146599999999
# 산돌교회 37.5771169 127.0841899
# 성균관대학교 37.5880437 126.9933924
# 신수중학교 37.546398700000005 126.9336747
# 남사초등학교 37.4827352 126.97889140000001
# 방화초등학교 37.5688885 126.8069612
# 대진초등학교 37.49698660000001 127.07775330000001
# 대모초등학교 37.4814125 127.0861939
# 경일중학교 37.543535399999996 127.0488162
# 건국대학교부속고등학교 37.5401648 127.0804549
# 우이제일교회 37.6599354 127.01031929999999
# 일심교회(12층) 37.5625589 126.9256035
# 곰달래경로당 37.5286161 126.83479990000001
# 구립대림1경로당 37.4954554 126.9059717
# 도림동 주민센터 37.509556700000005 126.8960031
# 길음초등학교 37.6140021 127.01781880000001
# 고일초등학교 37.552526799999995 127.16892050000001
# 서강동주민센터 강당 37.5592958 126.93059720000001
# 강남교회 37.5103395 126.94514540000002
# 한국예술고 37.5651319 127.03465700000001
# 신현초등학교 37.605823799999996 127.0932408
# 영파여자중학교 37.5325474 127.1197653
# 경희대동서신의학병원 37.553557 127.1575755
# 성내2동 주민센터 37.532436100000005 127.12955840000001
# 신답교회 37.571788399999996 127.0588047
# 광장중학교 37.547103899999996 127.10161459999999
# 서울자운초등학교 37.6579022 127.0466311
# 숭인초등학교 37.609097799999994 127.03842709999999
# 고덕초등학교 37.5610494 127.1665402
# 동교초등학교 37.558332799999995 126.9020726
# 중화2동 문화복지센터 37.5949689 127.07500759999999
# 영림초등학교 37.487349 126.90254540000001
# 연서경로당 37.565691799999996 126.9187633
# 하계중학교 37.6411204 127.07158259999999
# 성락교회 37.5051409 126.9027647
# 구일고등학교 37.4941903 126.8739442
# 회기동 주민센터 37.5908104 127.0553972
# 사당2동주민센터 37.4887286 126.97924040000001
# 구로중학교 37.4947492 126.89034540000002
# 금옥초교 37.546056899999996 127.01734009999998
# 영란여자중학교 37.603626299999995 127.10543419999999
# 석계초등학교 37.6087583 127.06991979999998
# 남성초등학교 37.4844111 126.97568159999999
# 한강초등학교 37.5252358 126.9651413
# 월정초등학교 37.5345552 126.8367024
# 방이초등학교 37.5134385 127.1205334
# 창서초등학교 37.557725399999995 126.93358880000001
# 학동초등학교 37.512176399999994 127.0394861
# 연희초등학교 37.569484100000004 126.93392450000002
# 서교초등학교 37.554986 126.92516979999999
# 수산교회 37.5976555 127.07594950000001
# 동안교회 37.5354546 127.12512530000001
# 압구정초등학교 37.5317333 127.0308305
# 서울가인초등학교 37.6601773 127.0435392
# 오류남초등학교 37.489575 126.8384794
# 가리봉동 주민센터 37.4813414 126.8934878
# 신우초등학교 37.4628024 126.93282820000002
# 구립모랫말 경로당 37.509732299999996 126.89751670000001
# 경산중고등학교 37.5909504 127.00140379999999
# 서빙고초등학교 37.521744700000006 126.99233000000001
# 구립양평4가 경로당 37.5381508 126.89628
# 상경중학교 37.6669473 127.0533922
# 성동초등학교 37.5332002 127.0895409
# 장평중학교 37.56659439999999 127.07092069999999
# 신일중학교 37.6282778 127.02818319999999
# 서울잠전초등학교 37.507076299999994 127.08437849999999
# 중화2동주민센터 37.6028284 127.07617900000001
# 숭신초등학교 37.571960100000005 127.0170331
# 신가초등학교 37.5003451 127.11976270000001
# 천호3동 주민센터 37.539829 127.129843
# 한양사범대 37.5582034 127.0451217
# 광진중학교 37.531980600000004 127.08962520000001
# 서울방학초등학교 37.6641576 127.03182959999998
# 중동고등학교 37.4936434 127.0811545
# 강동롯데캐슬경로당 37.55548220000001 127.141504
# 성내1동 주민센터 37.530474700000006 127.12247520000001
# 연동경로당 37.5655809 126.9237706
# 신정초등학교 37.5328907 126.85266340000001
# 신곡초등학교 37.5389557 126.8557082
# 안천중학교 37.4595098 126.8875085
# 서림경로당 37.4722792 126.9406116
# 도곡2문화센터 37.4837549 127.04647549999999
# 개봉1동 주민센터 37.5000383 126.8510764
# 개봉3동 주민센터 37.4860026 126.8538531
# 목동초등학교 37.5228069 126.87214540000001
# 수명 경로당 37.5408474 126.8343592
# 우성3차아파트 경로당 37.49664310000001 126.9090679
# 방화구립 경로당 37.5697848 126.81391
# 연가초등학교 37.579953499999995 126.91785530000001
# 오류초등학교 37.4983656 126.8424497
# 영남중학교 37.4978787 126.8958527
# 청량초등학교 37.5923035 127.0559615
# 성답교회 37.5646332 127.05123290000002
# 연희미용고등학교 37.479212 126.89449850000001
# 양목초등학교 37.523768700000005 126.8616908
# 구로3동 주민센터 37.4857776 126.89330530000001
# 서교동교회 37.5524501 126.91977620000002
# 문래초등학교 37.5185604 126.8935426
# 관악고등학교 37.521834000000005 126.8825947
# 서울구로남초등학교 37.4849993 126.8908446
# 도신초등학교 37.498749700000005 126.90118500000001
# 경성고등학교 37.5634175 126.9190284
# 새말경로당 37.5398815 126.8700818
# 중구민회관 37.568497 127.00624609999998
# 난향초등학교 37.4622696 126.9175362
# 태영 경로당 37.5456165 126.9428183
# 우이초등학교 37.638822499999996 127.01504569999999
# 영풍초등학교 37.496198299999996 127.14322609999999
# 문덕초등학교 37.485074299999994 127.1279596
# 신천초등학교 37.5140066 127.09504679999999
# 옥정초교 37.541864700000005 127.01526480000001
# 강북청소년수련관 37.64589539999999 127.0062436
# 휘경2동 주민센터 37.588121 127.0562553
# 삼각산중학교 37.616224 127.0154254
# 석촌초등학교 37.502931700000005 127.1045978
# 송파중학교 37.4959523 127.12994590000001
# 세검정초등학교 37.6033412 126.9609868
# 고척중학교 37.5001442 126.8621388
# 수유초등학교 37.6309352 127.0201095
# 오금초등학교 37.5093623 127.13197949999999
# 원효1동자치회관 37.538643 126.965921
# 고경경로당 37.497421100000004 126.9539659
# 서울동북초등학교 37.6549766 127.02603049999999
# 오금고등학교 37.5047211 127.12935230000001
# 신가경로당 37.580167200000005 126.90837409999999
# 대한예수교장로회 북아현교회 37.5638685 126.95144979999999
# 전농초등학교 37.574614399999994 127.054402
# 아현감리교회 37.5577433 126.9588344
# 신동아(아)관리사무소 37.517742600000005 126.9877673
# 내곡동 주민센터 37.4619494 127.0512045
# 공릉중학교 37.622368 127.08364089999999
# 광성교회 37.5378318 127.12267779999999
# 상곡초등학교 37.6627426 127.06253149999999
# 명성교회 예루살렘관 37.548234 127.1481451
# 강동성심병원 37.5361261 127.13537990000002
# 용마초등학교 37.5582216 127.0844446
# 용마중학교 37.5742948 127.08596270000001
# 풍납동 천주교회 37.5305076 127.11863909999998
# 금북초교 37.55731110000001 127.0235263
# 신도봉중학교 37.6496153 127.0333463
# 염리초등학교 37.542691600000005 126.94599509999999
# 삼각교회 37.5334763 126.97131170000002
# 용신동 주민센터 37.5761096 127.0303341
# 인수초등학교 37.6428859 127.00960970000001
# 세곡문화센터 37.469057299999996 127.10693290000002
# 선민교회(지하1층) 37.5420908 126.94272659999999
# 장안2동 주민센터 37.5784794 127.0706106
# 번동초등학교 37.6292746 127.0404438
# 용두초등학교 37.5761546 127.0288143
# 용산문화체육센터 37.537151 126.96768840000001
# 상지초등학교(체육관) 37.5796863 126.88244420000001
# 명일1동 주민센터 37.5497679 127.1460008
# 신서초등학교 37.520574100000005 126.86230630000001
# 포이초등학교 37.4759632 127.0531898
# 무지개 경로당 37.5340451 126.86083500000001
# 신석초등학교 37.5443423 126.9380392
# 동의초등학교 37.5534721 127.09914209999998
# 평창동주민센터 37.6054224 126.96693640000001
# 현장민원실 37.513089799999996 126.9560632
# 발음 경로당 37.5520498 126.83322279999999
# 가락중학교 37.502447499999995 127.11889740000002
# 언북초등학교 37.519853499999996 127.04512609999999
# 연희동주민센터 37.5738682 126.93524740000002
# 온조대왕문화체육관 37.556441299999996 127.157416
# 서울 서래 초등학교 37.49630620000001 126.98934340000001
# 신내초등학교 37.6047239 127.10011159999999
# 동빙고교회 37.5223266 126.99464409999999
# 신길6동 주민센터 37.499388 126.90966509999998
# 신내노인요양원 37.616244099999996 127.0949148
# 구로2동 주민센터 37.4913961 126.8832763
# 서울당곡초등학교 37.4903019 126.9297162
# 덕원중학교 37.5485578 126.8287486
# 서울개봉초등학교 37.489698700000005 126.85837109999999
# 영등포본동 주민센터 37.514675399999994 126.9093581
# 신길교회 37.515149900000004 126.91946709999999
# 오현초등학교 37.6232225 127.04623970000002
# 계상초등학교 37.662852799999996 127.0681084
# 서울개명초등학교 37.4828229 126.8506416
# 대동초등학교 37.4936638 126.8998145
# 복종 경로당 37.5739006 126.80780659999999
# 구로초등학교 37.4972518 126.8859504
# 월계초등학교 37.6279343 127.05084529999999
# 신묵초등학교 37.6074943 127.07551310000001
# 합정동주민센터 (강당 37.5494364 126.9057654
# 장승중학교 37.503778999999994 126.94067549999998
# 만민중앙선교회 37.4810545 126.8945545
# 영남교회 37.518650799999996 126.90156540000001
# 여의동 주민센터 37.5176665 126.9346068
# 서울창원초등학교 37.652615600000004 127.0401785
# 망원초등학교 37.560857399999996 126.90098870000001
# 은로초등학교 37.503164500000004 126.96002630000001
# 서울 언남초등학교 37.463921 127.0516668
# 한내들어린이집 37.6042154 127.07501979999999
# 장로회신학대학교 37.5503821 127.1038409
# 웰빙스포츠센터 37.6305229 127.03768600000001
# 용원초등학교 37.6297145 127.0687071
# 서울창도초등학교 37.664038399999995 127.04952240000001
# 월촌초등학교 37.5402148 126.8768478
# 대림정보문화도서관 37.50431270000001 126.89608899999999
# 온수초등학교 37.494139000000004 126.82598459999998
# 상원초등학교 37.6676601 127.0596237
# 금옥중학교 37.510394299999994 126.84365659999999
# 언주초등학교 37.4869806 127.0370764
# 수정성결교회 37.50075820000001 126.8980828
# 금양초등학교 37.5407467 126.96110829999999
# 서울창림초등학교 37.64327670000001 127.0413972
# 강남초교 37.5062024 126.953443
# 성암국제무역고 37.6209013 127.02465320000002
# 동작고등학교 37.4824203 126.96491019999999
# 구로1동 주민센터 37.493046 126.87580559999999
# 방배중학교 37.4942305 126.99849750000001
# 평화초등학교 37.491599 127.1228021
# 홍성교회 37.5978567 126.9491956
# 송원초교 37.5540565 127.06949569999999
# 중화중학교 37.5845501 127.09525759999998
# 숭의여자고등학교 37.5075802 126.9288845
# 동빙고할머니경로당 37.5228929 126.9964304
# 평강교회 37.5554785 126.962078
# 제기동 주민센터 37.5837333 127.034679
# 천동초등학교 37.5406167 127.138015
# 둔촌1동 주민센터 37.5234889 127.13674250000001
# 논현2문화복지회관 37.517267700000005 127.037204
# 현강여자정보고등학교 37.536319 127.1331341
# 풍납초등학교 37.534636299999995 127.11792890000001
# 도성초등학교 37.501180700000006 127.04903859999999
# 송중초등학교 37.617084600000005 127.0313824
# 청량리동 주민센터 37.5862863 127.04729809999999
# 봉바위 경로당 37.5432392 126.84140929999998
# 신서중학교 37.515911200000005 126.8558493
# 내발산 경로당 37.5541789 126.8401206
# 낙루경로당 37.570733399999995 126.90649340000002
# 공원 경로당 37.5380327 126.83854129999999
# 신덕교회 대예배실 37.5443365 126.9554285
# 삼성1문화센터 37.514353899999996 127.062504
# 성수중학교 37.548207500000004 127.03836729999999
# 한강미디어고등학교 37.53930820000001 126.8971258
# 장위초등학교 37.612407399999995 127.04998370000001
# 성내3동 주민센터 37.5260467 127.1329027
# 관악초등학교 37.4806388 126.9431002
# 삼선초등학교 37.586644299999996 127.01232659999998
# 해공도서관 37.5439366 127.1256067
# 을지초등학교 37.6507925 127.0731328
# 선화예술학교(중학교) 37.5501512 127.08758219999999
# 홍제3동주민센터 37.5937638 126.94971059999999
# 원광종합복지관 37.6043596 127.0959559
# 원묵초등학교 37.6179826 127.0862899
# 중원초등학교 37.6438528 127.06280559999999
# 암사3동 주민센터 37.554997799999995 127.140775

# %%
# 지도를 생성한 뒤, 위도/경도에 맞게 지도에 마커를 추가하겠습니다. 

# 지도 생성하기
m = folium.Map(location=[37.5536067,126.9674308],
               zoom_start=12)
m
# 대피소 마커 추가하기

for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i,'대피소명칭']

    folium.Marker([lat, long],tooltip= name).add_to(m)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 이름 깨질때 해결하기 위해서는 폴리움을 다운그레이드 하거나
# html파일로 저장해서 확인하는 방법이있다

# %%
m.save('./')

# %% [markdown]
# ### 마커가 너무 많을때에는 살펴보는 것이 어려울 수 있습니다.
# ### --> ClusterMarker를 이용해  근처에 있는 마커들끼리는 그룹으로 표현

# %%
# MarkerCluster   라이브러리를 불러오겠습니다. 
from folium.plugins import MarkerCluster

# %%
# MarkerCluster 를 이용해 대피소 정보를 지도에 시각화 하겠습니다. 

# 지도 생성하기
m = folium.Map(location=[37.5536067,126.9674308],
               zoom_start=12)
marker_cluster = MarkerCluster().add_to(m)  # 클러스터 추가하기

# 대피소 마커 추가하기

for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i,'대피소명칭']
    folium.Marker([lat, long],
                tooltip = name).add_to(marker_cluster)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
raw.head()
# Out:
#    고유번호     대피소명칭                소재지  최대수용인원  현재수용인원 현재운영여부           전화번호  \
# 0     2    혜화초등학교  혜화동 13-1 (혜화로 32)     450       0      N       763-0606
# 1     3      새샘교회           홍제동 20-4     100       0      N       720-7040
# 2     4    한강중앙교회     포은로2가길 66(합정동)     130       0      N       337-6629
# 3     5  서울성산초등학교      양화로3길 94(합정동)     200       0      N       324-1407
# 4     6   상도1동경로당        상도동 159-282      20       0      N  010-8011-7330
#
#       행정동코드 행정동명칭 대피단계 비고          경도         위도
# 0  11110650   혜화동          126.999891  37.589128
# 1  11410655  홍제2동          126.950484  37.583660
# 2  11440680   합정동          126.910028  37.549343
# 3  11440680   합정동          126.910666  37.553495
# 4  11590530  상도1동          126.948269  37.500395

# %% [markdown]
# ### 미니맵 추가하고 싶을때에는
# ## MiniMap

# %%
# 앞서 살펴봤떤 미니맵도 추가해보겠습니다. 
from folium.plugins import MiniMap

# %%
# 미니맵과 클러스터 마커를 이용하여   서울 대피소 지도를 만들겠습니다. 

# 위치명 / 수용인원 등 추가 정보 추가하여 지도 만들기
# 지도 생성하기
m = folium.Map(location=[37.5536067,126.9674308],
               zoom_start=12)
# 클러스터 만들기
marker_cluster = MarkerCluster().add_to(m)

# 미니맵 추가하기
minimap = MiniMap() 
m.add_child(minimap)

# 대피소 마커 추가하기

for i in range(len(raw)):
    lat = raw.loc[i, '위도']
    long = raw.loc[i, '경도']
    name = raw.loc[i,'대피소명칭']
    folium.Marker([lat, long], tooltip = name).add_to(marker_cluster)    
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 이렇게 생성한 지도를 html 확장자로 저장할 경우, 
# 필요할때에는 언제나 다시 열어서 지도를 움직여 가며 정보를 확인할 수 있습니다. 
# 지도를 저장해보겠습니다 .

m.save('./data/Sheltermap.html')
